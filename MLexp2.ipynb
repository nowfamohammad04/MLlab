# %%
import math

num = 9
angle_degrees = 45

print("Square Root:", math.sqrt(num))
print("Factorial:", math.factorial(5))
print("Logarithm base 10:", math.log10(100))
print("Sine of 45 degrees:", math.sin(math.radians(angle_degrees)))
print("Value of Pi:", math.pi)
# Out:
# Square Root: 3.0
# Factorial: 120
# Logarithm base 10: 2.0
# Sine of 45 degrees: 0.7071067811865475
# Value of Pi: 3.141592653589793

# %%
import math

# %%
num = 9

# %%
print("Squre Root:",math.sqrt(num))
# Out:
# Squre Root: 3.0

# %%
print("Factorial:",math.factorial(num))
# Out:
# Factorial: 362880

# %%
print("Logarithm base:",math.log10(num))
# Out:
# Logarithm base: 0.9542425094393249

# %%
print("Sine of 45 degree:",math.sin(math.radians(num)))
# Out:
# Sine of 45 degree: 0.15643446504023087

# %%
print("Value of Pi:",math.pi)
# Out:
# Value of Pi: 3.141592653589793

# %%
import numpy as np

a = np.array([1, 2, 3])
print(type(a))
print(a.shape)
print(a[0], a[1], a[2])
a[0] = 5
print(a)
b = np.array([[1,2,3],[4,5,6]])
print(b.shape)
print(b[0, 0], b[0, 1], b[1, 0])
# Out:
# <class 'numpy.ndarray'>
# (3,)
# 1 2 3
# [5 2 3]
# (2, 3)
# 1 2 4

# %%
num1 = -0.4
num2 = 6.9
num3 = -9.5
num4 =  4.99

# %%
print("ceil of",num1,"is:",math.ceil(num1))
# Out:
# ceil of -0.4 is: 0

# %%
print("ceil of",num2,"is:",math.ceil(num2))
# Out:
# ceil of 6.9 is: 7

# %%
print("ceil of",num3,"is:",math.ceil(num3))
print("ceil of",num4,"is:",math.ceil(num4))
# Out:
# ceil of -9.5 is: -9
# ceil of 4.99 is: 5
